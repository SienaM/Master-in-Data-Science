# %% [markdown]
# ### Contamos el número de líneas de un fichero comprimido sin descomprimirlo

# %%
import bz2

# %%
f = bz2.BZ2File('bookings.csv.bz2')

# %%
f

# %%
# Realizamos un proceso iterativo que no consume tanta memoria
n= 0
for l in f:
    n += 1

# %%
n
# Out:
# 10000011
